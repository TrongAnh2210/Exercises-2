# %% [markdown]
# <a href="https://colab.research.google.com/github/TrongAnh2210/Exercises-2/blob/main/Exercises2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Mục mới

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %% [markdown]
# ***Số huy chương Vàng của USA qua các năm ***

# %%
import pandas as pd
dataframe = pd.read_csv(url)
dataframe[(dataframe['NOC'] == 'USA')&(dataframe['Medal'] == 'Gold')].head(1000)
# Out:
#       Year         City      Sport     Discipline  NOC            Event  \
# 47    1924     Chamonix    Skating  Speed skating  USA             500m
# 84    1928   St. Moritz  Bobsleigh      Bobsleigh  USA         five-man
# 86    1928   St. Moritz  Bobsleigh       Skeleton  USA       individual
# 120   1932  Lake Placid  Bobsleigh      Bobsleigh  USA         four-man
# 123   1932  Lake Placid  Bobsleigh      Bobsleigh  USA          two-man
# ...    ...          ...        ...            ...  ...              ...
# 2301  2006        Turin     Skiing  Alpine Skiing  USA  Alpine combined
# 2302  2006        Turin     Skiing  Alpine Skiing  USA     giant slalom
# 2305  2006        Turin     Skiing      Snowboard  USA        Half-pipe
# 2307  2006        Turin     Skiing      Snowboard  USA        Half-pipe
# 2309  2006        Turin     Skiing      Snowboard  USA  Snowboard Cross
#
#      Event gender Medal
# 47              M  Gold
# 84              M  Gold
# 86              M  Gold
# ...

# %% [markdown]
# ### **Số huy chương bạc của USA qua các năm **

# %%
dataframe[(dataframe['NOC'] == 'USA')&(dataframe['Medal'] == 'Silver')].head(1000)
# Out:
#       Year         City       Sport      Discipline  NOC            Event  \
# 45    1924     Chamonix  Ice Hockey      Ice Hockey  USA       ice hockey
# 46    1924     Chamonix     Skating  Figure skating  USA       individual
# 85    1928   St. Moritz   Bobsleigh       Bobsleigh  USA         five-man
# 87    1928   St. Moritz   Bobsleigh        Skeleton  USA       individual
# 121   1932  Lake Placid   Bobsleigh       Bobsleigh  USA         four-man
# ...    ...          ...         ...             ...  ...              ...
# 2296  2006        Turin     Skating   Speed skating  USA            1000m
# 2298  2006        Turin     Skating   Speed skating  USA            1500m
# 2306  2006        Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006        Turin      Skiing       Snowboard  USA        Half-pipe
# 2310  2006        Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 45              M  Silver
# ...

# %% [markdown]
# ### **Số huy chương đồng của USA qua các năm **

# %%
dataframe[(dataframe['NOC'] == 'USA')&(dataframe['Medal'] == 'Bronze')].head(1000)
# Out:
#       Year                    City       Sport      Discipline  NOC  \
# 48    1924                Chamonix      Skiing     Ski Jumping  USA
# 88    1928              St. Moritz     Skating  Figure skating  USA
# 89    1928              St. Moritz     Skating   Speed skating  USA
# 122   1932             Lake Placid   Bobsleigh       Bobsleigh  USA
# 125   1932             Lake Placid     Skating  Figure skating  USA
# 179   1936  Garmisch-Partenkirchen   Bobsleigh       Bobsleigh  USA
# 181   1936  Garmisch-Partenkirchen  Ice Hockey      Ice Hockey  USA
# 182   1936  Garmisch-Partenkirchen     Skating   Speed skating  USA
# 242   1948              St. Moritz   Bobsleigh       Bobsleigh  USA
# 244   1948              St. Moritz   Bobsleigh       Bobsleigh  USA
# 310   1952                    Oslo     Skating  Figure skating  USA
# 383   1956       Cortina d'Ampezzo   Bobsleigh       Bobsleigh  USA
# 385   1956       Cortina d'Ampezzo     Skating  Figure skating  USA
# ...

# %% [markdown]
# ### **Số huy chương theo từng bộ môn của USA**

# %%
fr = dataframe.groupby('Sport').count()
dataframe
frame = dataframe[(dataframe['NOC'] == 'USA')]
frame.groupby('Sport').count()
# Out:
#             Year  City  Discipline  NOC  Event  Event gender  Medal
# Sport
# Bobsleigh     24    24          24   24     24            24     24
# Curling        1     1           1    1      1             1      1
# Ice Hockey    12    12          12   12     12            12     12
# Luge           4     4           4    4      4             4      4
# Skating      118   118         118  118    118           118    118
# Skiing        57    57          57   57     57            57     57
